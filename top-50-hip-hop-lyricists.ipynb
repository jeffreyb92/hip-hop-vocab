# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#importing the excel file
vocab = pd.ExcelFile(r'Hip Hop _ Vocab Chart.xlsx')

# %%
#checking the sheet names to see what I need
vocab.sheet_names
# Out:
# ['Artist Album Links', 'Sheet8', 'Full']

# %%
#importing the full sheet to look at the data
fullsheet = pd.read_excel(r'Hip Hop _ Vocab Chart.xlsx', sheet_name = 'Full')

# %%
#checking how many rows. Looks like there's 186 artists
len(fullsheet)
# Out:
# 186

# %%
#checking the columns to see what's happening
fullsheet.head()
# Out:
#   notes  recalc    era     rapper rapper_clean                 color words  \
# 0   NaN  2988.0  2010s  21 Savage    21 Savage                   NaN  2988
# 1   NaN  3812.0  2010s   2 Chainz     2 Chainz                   NaN  4148
# 2   NaN  3815.0  1990s       2Pac         2Pac  west nowutang second  3970
# 3   NaN  3384.0  2000s    50 Cent      50 Cent   east nowutang first  3591
# 4   NaN  4534.0  2010s    Ab-Soul      Ab-Soul                   NaN  4534
#
#           id  source
# 0  21-savage     new
# 1    2chainz  poster
# 2       2pac    site
# 3    50-cent    site
# 4     absoul     new

# %%
#taking only the rows that have info that I could go off of
improvedfullsheet = fullsheet[['id','rapper','era','recalc']]

# %%
#dropping NaN values that might be in those columns
improvedfullsheet = improvedfullsheet.dropna()

# %%
#checking how many rows dropped. Looks like 26 artists got dropped
len(improvedfullsheet)
# Out:
# 160

# %%
#renaming the 'recalc' column to words since it seems that the actual value
improvedfullsheet = improvedfullsheet.rename(columns = {'recalc': 'words'})

# %%
#sorting the data by the words count
improvedfullsheetsort = improvedfullsheet.sort_values(by = 'words', ascending = False)

# %%
plt.bar(improvedfullsheet['rapper'], improvedfullsheet['words'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 160 artists>

# %%
#Technically the top 50 Hip Hop artists of all time in terms of words used in their music
#Fun fact: It takes until number 21 (Watsky) for an artists in the 2010s to be in the top
#Fun fact 2: Jean Grae is the top female Hip Hop artist in place number 14
top_50 = improvedfullsheetsort.head(50)
top_50
# Out:
#                      id                               rapper    era   words
# 6                 aesop                           Aesop Rock  2000s  7879.0
# 24            busdriver                            Busdriver  2000s  7324.0
# 68                 jedi                     Jedi Mind Tricks  2000s  6424.0
# 57                  gza               GZA (only solo albums)  1990s  6390.0
# 156             wu-tang                         Wu-Tang Clan  1990s  6196.0
# 106             mf-doom                              MF DOOM  2000s  6169.0
# 131                 rza               RZA (only solo albums)  2000s  6018.0
# 61             immortal                   Immortal Technique  2000s  5930.0
# 27              canibus                              Canibus  2000s  5915.0
# 54     ghostface-killah  Ghostface Killah (only solo albums)  2000s  5901.0
# 38                  del             Del the Funky Homosapian  1990s  5845.0
# 127               roots                            The Roots  1990s  5781.0
# 16        blackalicious                        Blackalicious  2000s  5741.0
# 67                 jean                            Jean Grae  2000s  5738.0
# 82        killah-priest                        Killah Priest  2000s  5704.0
# 85           kool-keith                           Kool Keith  1990s  5566.0
# 84           kool-g-rap                           Kool G Rap  1990s  5554.0
# 31      cunninlynguists                      CunninLynguists  2000s  5496.0
# 132                sage                         Sage Francis  2000s  5443.0
# 120             raekwon           Raekwon (only solo albums)  1990s  5428.0
# 154              watsky                               Watsky  2010s  5413.0
# 5                action                       Action Bronson  2010s  5233.0
# 122              redman                               Redman  1990s  5196.0
# 35              das-efx                              Das EFX  1990s  5178.0
# 30               common                               Common  1990s  5138.0
# 75                 kaan                                 KAAN  2010s  5107.0
# 43                 e-40                                 E-40  1990s  5004.0
# 55           goodie-mob                           Goodie Mob  1990s  4980.0
# 112                 nas                                  Nas  1990s  4977.0
# 22          brother-ali                          Brother Ali  2000s  4928.0
# 105          method-man        Method Man (only solo albums)  1990s  4910.0
# 47             flatbush                     Flatbush Zombies  2010s  4879.0
# 70                 joey                          Joey BadA$$  2010s  4871.0
# 145  tribe-called-quest                 A Tribe Called Quest  1990s  4838.0
# 110             mos-def                              Mos Def  2000s  4827.0
# 36           de-la-soul                           De La Soul  1990s  4812.0
# 157              xzibit                               Xzibit  2000s  4787.0
# 111                murs                                 Murs  2000s  4772.0
# 126               rittz                                Rittz  2010s  4757.0
# 9            atmosphere                           Atmosphere  2000s  4730.0
# 140         talib-kweli                          Talib Kweli  2000s  4678.0
# 11       big-daddy-kane                       Big Daddy Kane  1980s  4655.0
# 98          lupe-fiasco                          Lupe Fiasco  2000s  4645.0
# 33         cypress-hill                         Cypress Hill  1990s  4644.0
# 95            ll-cool-j                            LL Cool J  1980s  4638.0
# 10         beastie-boys                         Beastie Boys  1980s  4632.0
# 46              fat-joe                              Fat Joe  1990s  4626.0
# 74               k-rino                               K-Rino  1999s  4620.0
# 25         busta-rhymes                         Busta Rhymes  1990s  4613.0
# 52           gang-starr                           Gang Starr  1990s  4598.0

# %%
plt.bar(top_50['rapper'],top_50['words'])
# Out:
# <BarContainer object of 50 artists>

# %%
#The bottom 50 Hip Hop Artists according to unique words used
bottom_50 = improvedfullsheetsort.tail(50)
bottom_50
# Out:
#                 id                      rapper    era   words
# 137          snoop                  Snoop Dogg  1990s  3797.0
# 48      foxy-brown                  Foxy Brown  1990s  3782.0
# 77      kanye-west                  Kanye West  2000s  3760.0
# 17             bob                         BoB  2010s  3748.0
# 108   missy-elliot                Missy Elliot  2000s  3747.0
# 101        machine           Machine Gun Kelly  2010s  3690.0
# 87          lecrae                      LeCrae  2000s  3687.0
# 28        childish            Childish Gambino  2010s  3682.0
# 71           juelz               Juelz Santana  2000s  3675.0
# 45             eve                         Eve  2000s  3642.0
# 115    nicki-minaj                 Nicki Minaj  2010s  3616.0
# 133    salt-n-pepa                 Salt-n-Pepa  1990s  3601.0
# 102       master-p                    Master P  1990s  3580.0
# 14        big-sean                    Big Sean  2010s  3563.0
# 147          trina                       Trina  2000s  3537.0
# 56      gucci-mane                  Gucci Mane  2000s  3515.0
# 130           russ                        Russ  2010s  3491.0
# 160    young-jeezy                 Young Jeezy  2000s  3486.0
# 93       lil-wayne                   Lil Wayne  2000s  3486.0
# 50          g-eazy                      G-Eazy  2010s  3468.0
# 104           meek                   Meek Mill  2010s  3454.0
# 146          trick                 Trick Daddy  2000s  3447.0
# 73        juvenile                    Juvenile  1990s  3442.0
# 63          j-cole                      J Cole  2010s  3426.0
# 161     young-thug                  Young Thug  2010s  3395.0
# 144   travis-scott                Travis Scott  2010s  3392.0
# 3          50-cent                     50 Cent  2000s  3384.0
# 42           drake                       Drake  2010s  3347.0
# 49          future                      Future  2010s  3321.0
# 80        kid-cudi                    Kid Cudi  2010s  3318.0
# 96           logic                       Logic  2010s  3281.0
# 72         juicy-j                     Juicy J  2000s  3275.0
# 18      bone-thugs        Bone Thugs-n-Harmony  1990s  3219.0
# 83           kodak                 Kodak Black  2010s  3197.0
# 107          migos                       Migos  2010s  3193.0
# 94      lil-yachty                  Lil Yachty  2010s  3161.0
# 81         kid-ink                     Kid Ink  2010s  3055.0
# 155    wiz-khalifa                 Wiz Khalifa  2010s  3048.0
# 158             yg                          YG  2010s  3029.0
# 90        lil-durk                    Lil Durk  2010s  2988.0
# 0        21-savage                   21 Savage  2010s  2988.0
# 41             dmx                         DMX  1990s  2936.0
# 123     rich-homie             Rich Homie Quan  2010s  2853.0
# 143      too-short                   Too Short  1980s  2778.0
# 89        lil-baby                    Lil Baby  2010s  2762.0
# 19   boogie-hoodie      A Boogie wit da Hoodie  2010s  2738.0
# 159      young-boy  YoungBoy Never Broke Again  2010s  2724.0
# 124   rich-the-kid                Rich the Kid  2010s  2709.0
# 92    lil-uzi-vert                Lil Uzi Vert  2010s  2556.0
# 114             nf                          NF  2010s  2472.0

# %%
plt.bar(bottom_50['rapper'], bottom_50['words'])
# Out:
# <BarContainer object of 50 artists>

# %%
# plt.savefig('rapper_word_chart.png')

# %%
#checking the average amount of words used as a whole. They averaged 4263 words per artist
improvedfullsheetsort.describe()
# Out:
#              words
# count   160.000000
# mean   4263.287500
# std     927.617293
# min    2472.000000
# 25%    3635.500000
# 50%    4204.000000
# 75%    4691.000000
# max    7879.000000

# %%
#creating a new dataframe based on the 1980s era
improved1980s = improvedfullsheet[improvedfullsheet['era'] == "1980s"]

# %%
#sorting them by unique words
improved1980s = improved1980s.sort_values(by = "words", ascending = False)

# %%
#top 1980s Hip Hop artits ranked by unique word count
improved1980s
# Out:
#                  id                             rapper    era   words
# 11   big-daddy-kane                     Big Daddy Kane  1980s  4655.0
# 95        ll-cool-j                          LL Cool J  1980s  4638.0
# 10     beastie-boys                       Beastie Boys  1980s  4632.0
# 15       biz-markie                         Biz Markie  1980s  4423.0
# 60            ice-t                              Ice T  1980s  4334.0
# 121           rakim  Rakim (including Eric B. & Rakim)  1980s  4301.0
# 129         run-dmc                         Run-D.M.C.  1980s  3899.0
# 143       too-short                          Too Short  1980s  2778.0

# %%
#checking the stats for the 1980s artists. They averaged 4207, just slightly below the overall average
improved1980s.describe()
# Out:
#              words
# count     8.000000
# mean   4207.500000
# std     629.695391
# min    2778.000000
# 25%    4200.500000
# 50%    4378.500000
# 75%    4633.500000
# max    4655.000000

# %%
plt.figure()
plt.bar(improved1980s['rapper'],improved1980s['words'])
plt.xticks(rotation=90)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#creating table for 1990s artists
improved1990s = improvedfullsheet[improvedfullsheet['era'] == "1990s"]

# %%
#sorting them by unique words count
improved1990s = improved1990s.sort_values(by = "words", ascending = False)

# %%
#ranking of 1990s Hip Hop artists by unique word counts
improved1990s
# Out:
#                                  id  \
# 57                              gza
# 156                         wu-tang
# 38                              del
# 127                           roots
# 85                       kool-keith
# 84                       kool-g-rap
# 120                         raekwon
# 122                          redman
# 35                          das-efx
# 30                           common
# 43                             e-40
# 55                       goodie-mob
# 112                             nas
# 105                      method-man
# 145              tribe-called-quest
# 36                       de-la-soul
# 33                     cypress-hill
# 46                          fat-joe
# 25                     busta-rhymes
# 52                       gang-starr
# 100                          macdre
# 86   krs-one-excl-boogie-production
# 116                         outkast
# 20                     brand-nubian
# 53                        geto-boys
# 59                         ice-cube
# 119                      puff-daddy
# 66                            jay-z
# 118                    public-enemy
# 109                       mobb-deep
# 13                            big-l
# 142                 three-six-mafia
# 62               insane-clown-posse
# 134                        scarface
# 151                             ugk
# 103                         mc-lyte
# 2                              2pac
# 137                           snoop
# 48                       foxy-brown
# 133                     salt-n-pepa
# 102                        master-p
# 73                         juvenile
# 18                       bone-thugs
# 41                              dmx
#
#                                                 rapper    era   words
# 57                              GZA (only solo albums)  1990s  6390.0
# 156                                       Wu-Tang Clan  1990s  6196.0
# 38                            Del the Funky Homosapian  1990s  5845.0
# 127                                          The Roots  1990s  5781.0
# 85                                          Kool Keith  1990s  5566.0
# 84                                          Kool G Rap  1990s  5554.0
# 120                         Raekwon (only solo albums)  1990s  5428.0
# 122                                             Redman  1990s  5196.0
# 35                                             Das EFX  1990s  5178.0
# 30                                              Common  1990s  5138.0
# 43                                                E-40  1990s  5004.0
# 55                                          Goodie Mob  1990s  4980.0
# 112                                                Nas  1990s  4977.0
# 105                      Method Man (only solo albums)  1990s  4910.0
# 145                               A Tribe Called Quest  1990s  4838.0
# 36                                          De La Soul  1990s  4812.0
# 33                                        Cypress Hill  1990s  4644.0
# 46                                             Fat Joe  1990s  4626.0
# 25                                        Busta Rhymes  1990s  4613.0
# 52                                          Gang Starr  1990s  4598.0
# 100                                            Mac Dre  1990s  4577.0
# 86   KRS-One (only solo albums, excl. boogie produc...  1990s  4571.0
# 116                                            Outkast  1990s  4545.0
# 20                                        Brand Nubian  1990s  4542.0
# 53                                           Geto Boys  1990s  4364.0
# 59                                            Ice Cube  1990s  4338.0
# 119                                         Puff Daddy  1990s  4323.0
# 66                                               Jay-Z  1990s  4275.0
# 118                                       Public Enemy  1990s  4261.0
# 109           Mobb Deep (incl. both Prodigy and Havoc)  1990s  4243.0
# 13                                               Big L  1990s  4011.0
# 142                                      Three 6 Mafia  1990s  3978.0
# 62                                  Insane Clown Posse  1990s  3905.0
# 134                                           Scarface  1990s  3902.0
# 151                                                UGK  1990s  3869.0
# 103                                            MC Lyte  1990s  3817.0
# 2                                                 2Pac  1990s  3815.0
# 137                                         Snoop Dogg  1990s  3797.0
# 48                                          Foxy Brown  1990s  3782.0
# 133                                        Salt-n-Pepa  1990s  3601.0
# 102                                           Master P  1990s  3580.0
# 73                                            Juvenile  1990s  3442.0
# 18                                Bone Thugs-n-Harmony  1990s  3219.0
# 41                                                 DMX  1990s  2936.0

# %%
#checking the stats. They averaged 4544 words, about 200 words more per artist, but also has almost 40 more artists
improved1990s.describe()
# Out:
#              words
# count    44.000000
# mean   4544.704545
# std     779.285200
# min    2936.000000
# 25%    3904.250000
# 50%    4558.000000
# 75%    4986.000000
# max    6390.000000

# %%
plt.figure()
plt.bar(improved1990s['rapper'],improved1990s['words'])
plt.xticks(rotation=90)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#creating table for 2000s artists
improved2000s = improvedfullsheet[improvedfullsheet['era'] == "2000s"]

# %%
#sorting by unique word counts
improved2000s = improved2000s.sort_values(by = 'words', ascending = False)

# %%
#Ranking of the 2000s Hip Hop Artists by unique word count
improved2000s
# Out:
#                    id                               rapper    era   words
# 6               aesop                           Aesop Rock  2000s  7879.0
# 24          busdriver                            Busdriver  2000s  7324.0
# 68               jedi                     Jedi Mind Tricks  2000s  6424.0
# 106           mf-doom                              MF DOOM  2000s  6169.0
# 131               rza               RZA (only solo albums)  2000s  6018.0
# 61           immortal                   Immortal Technique  2000s  5930.0
# 27            canibus                              Canibus  2000s  5915.0
# 54   ghostface-killah  Ghostface Killah (only solo albums)  2000s  5901.0
# 16      blackalicious                        Blackalicious  2000s  5741.0
# 67               jean                            Jean Grae  2000s  5738.0
# 82      killah-priest                        Killah Priest  2000s  5704.0
# 31    cunninlynguists                      CunninLynguists  2000s  5496.0
# 132              sage                         Sage Francis  2000s  5443.0
# 22        brother-ali                          Brother Ali  2000s  4928.0
# 110           mos-def                              Mos Def  2000s  4827.0
# 157            xzibit                               Xzibit  2000s  4787.0
# 111              murs                                 Murs  2000s  4772.0
# 9          atmosphere                           Atmosphere  2000s  4730.0
# 140       talib-kweli                          Talib Kweli  2000s  4678.0
# 98        lupe-fiasco                          Lupe Fiasco  2000s  4645.0
# 97           ludacris                             Ludacris  2000s  4572.0
# 69         joe-budden                           Joe Budden  2000s  4523.0
# 148            twista                               Twista  2000s  4522.0
# 44             eminem                               Eminem  2000s  4480.0
# 141         tech-nine                            Tech n9ne  2000s  4406.0
# 128      royce-da-5-9                         Royce da 5'9  2000s  4392.0
# 79        kevin-gates                          Kevin Gates  2000s  4318.0
# 26             camron                              Cam'ron  2000s  4236.0
# 51               game                             The Game  2000s  4236.0
# 64           jadakiss                             Jadakiss  2000s  4172.0
# 139              t-i-                                 T.I.  2000s  4171.0
# 91            lil-kim                             Lil' Kim  2000s  4150.0
# 76               kano                                 Kano  2000s  4144.0
# 113             nelly                                Nelly  2000s  4091.0
# 136            skyzoo                               Skyzoo  2000s  3931.0
# 125          rickross                            Rick Ross  2000s  3907.0
# 23               bunb                                Bun B  2000s  3875.0
# 40      dizzee-rascal                        Dizzee Rascal  2000s  3863.0
# 77         kanye-west                           Kanye West  2000s  3760.0
# 108      missy-elliot                         Missy Elliot  2000s  3747.0
# 87             lecrae                               LeCrae  2000s  3687.0
# 71              juelz                        Juelz Santana  2000s  3675.0
# 45                eve                                  Eve  2000s  3642.0
# 147             trina                                Trina  2000s  3537.0
# 56         gucci-mane                           Gucci Mane  2000s  3515.0
# 160       young-jeezy                          Young Jeezy  2000s  3486.0
# 93          lil-wayne                            Lil Wayne  2000s  3486.0
# 146             trick                          Trick Daddy  2000s  3447.0
# 3             50-cent                              50 Cent  2000s  3384.0
# 72            juicy-j                              Juicy J  2000s  3275.0

# %%
#checking 2000s Hip hop artists word stats. They averaged 4633 words per artists, slightly more than the last era, but with 6 more artists
improved2000s.describe()
# Out:
#              words
# count    50.000000
# mean   4633.580000
# std    1045.522096
# min    3275.000000
# 25%    3866.000000
# 50%    4399.000000
# 75%    5314.250000
# max    7879.000000

# %%
plt.figure()
plt.bar(improved2000s['rapper'],improved2000s['words'])
plt.xticks(rotation=90)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#creating a table for 2010s Hip Hop Artists
improved2010s = improvedfullsheet[improvedfullsheet['era'] == "2010s"]

# %%
#sorting the table by unique word counts
improved2010s = improved2010s.sort_values(by = "words", ascending = False)

# %%
#ranking of the 2010s Hip Hop Artists by unique word count
improved2010s
# Out:
#                 id                      rapper    era   words
# 154         watsky                      Watsky  2010s  5413.0
# 5           action              Action Bronson  2010s  5233.0
# 75            kaan                        KAAN  2010s  5107.0
# 47        flatbush            Flatbush Zombies  2010s  4879.0
# 70            joey                 Joey BadA$$  2010s  4871.0
# 126          rittz                       Rittz  2010s  4757.0
# 4           absoul                     Ab-Soul  2010s  4534.0
# 150          tyler           Tyler the Creator  2010s  4431.0
# 39          denzel                Denzel Curry  2010s  4426.0
# 7             asap                  A$AP Rocky  2010s  4414.0
# 138    suicideboys                 $uicideboy$  2010s  4374.0
# 34           danny                 Danny Brown  2010s  4361.0
# 37           death                 Death Grips  2010s  4282.0
# 153           wale                        Wale  2010s  4272.0
# 65        jay-rock                    Jay Rock  2010s  4163.0
# 135      schoolboy                 ScHoolboy Q  2010s  4097.0
# 78        kendrick              Kendrick Lamar  2010s  4017.0
# 32        cupcakke                    Cupcakke  2010s  3965.0
# 99      mac-miller                  Mac Miller  2010s  3960.0
# 149           tyga                        Tyga  2010s  3946.0
# 21    brockhampton                Brockhampton  2010s  3924.0
# 58          hopsin                      Hopsin  2010s  3898.0
# 152          vince               Vince Staples  2010s  3883.0
# 8        asap-ferg                   A$AP Ferg  2010s  3851.0
# 88           lil-b                       Lil B  2010s  3842.0
# 12        big-krit                    Big KRIT  2010s  3823.0
# 1          2chainz                    2 Chainz  2010s  3812.0
# 17             bob                         BoB  2010s  3748.0
# 101        machine           Machine Gun Kelly  2010s  3690.0
# 28        childish            Childish Gambino  2010s  3682.0
# 115    nicki-minaj                 Nicki Minaj  2010s  3616.0
# 14        big-sean                    Big Sean  2010s  3563.0
# 130           russ                        Russ  2010s  3491.0
# 50          g-eazy                      G-Eazy  2010s  3468.0
# 104           meek                   Meek Mill  2010s  3454.0
# 63          j-cole                      J Cole  2010s  3426.0
# 161     young-thug                  Young Thug  2010s  3395.0
# 144   travis-scott                Travis Scott  2010s  3392.0
# 42           drake                       Drake  2010s  3347.0
# 49          future                      Future  2010s  3321.0
# 80        kid-cudi                    Kid Cudi  2010s  3318.0
# 96           logic                       Logic  2010s  3281.0
# 83           kodak                 Kodak Black  2010s  3197.0
# 107          migos                       Migos  2010s  3193.0
# 94      lil-yachty                  Lil Yachty  2010s  3161.0
# 81         kid-ink                     Kid Ink  2010s  3055.0
# 155    wiz-khalifa                 Wiz Khalifa  2010s  3048.0
# 158             yg                          YG  2010s  3029.0
# 90        lil-durk                    Lil Durk  2010s  2988.0
# 0        21-savage                   21 Savage  2010s  2988.0
# 123     rich-homie             Rich Homie Quan  2010s  2853.0
# 89        lil-baby                    Lil Baby  2010s  2762.0
# 19   boogie-hoodie      A Boogie wit da Hoodie  2010s  2738.0
# 159      young-boy  YoungBoy Never Broke Again  2010s  2724.0
# 124   rich-the-kid                Rich the Kid  2010s  2709.0
# 92    lil-uzi-vert                Lil Uzi Vert  2010s  2556.0
# 114             nf                          NF  2010s  2472.0

# %%
#checking the stats for 2010s Hip Hop artists. They averaged 3722 words per artists, with the most amount of rappers and yet under 500 words less than previous eras.
#This could be due to the fact that the other artists have had more time rapping, or that artists are simply using less unique words in their songs than previous.
improved2010s.describe()
# Out:
#              words
# count    57.000000
# mean   3722.807018
# std     697.193134
# min    2472.000000
# 25%    3197.000000
# 50%    3690.000000
# 75%    4163.000000
# max    5413.000000

# %%
plt.figure()
plt.bar(improved2010s['rapper'],improved2010s['words'])
plt.xticks(rotation=90)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20,15))
fig.suptitle("Unique Word Count per Rapper by Era", size = 24, va= 'top')

improved1980s.plot(kind='bar', x='rapper', ax=axes[0,0], ylim=(0,8000), legend=False)
axes[0,0].set_title("1980s Rappers")

improved1990s.plot(kind='bar', x='rapper', color='black', ax=axes[0,1], ylim=(0,8000), legend=False)
axes[0,1].set_title("1990s Rappers")

improved2000s.plot(kind='bar', x='rapper', color='red', ax=axes[1,0], ylim=(0,8000), legend=False)
axes[1,0].set_title("2000s Rappers")

improved2010s.plot(kind='bar', x='id', color = 'green', ax=axes[1,1], ylim=(0,8000), legend=False)
axes[1,1].set_title("2010s Rappers")


# fig.subplots_adjust(hspace=0.45,wspace=0.1)
plt.tight_layout(pad=6)
plt.savefig('word_count_by_era.png')
# Out:
# <img src="data:image/png;base64,..." width="2000">
