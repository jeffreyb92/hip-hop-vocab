# %%
import pandas as pd
import numpy as np

# %%
vocab = pd.ExcelFile(r'Hip Hop _ Vocab Chart.xlsx')

# %%
vocab.sheet_names
# Out:
# ['Artist Album Links', 'Sheet8', 'Full']

# %%
artistlinks = pd.read_excel(r'Hip Hop _ Vocab Chart.xlsx', sheet_name = 'Artist Album Links')

# %%
len(artistlinks)
# Out:
# 591

# %%
fullsheet = pd.read_excel(r'Hip Hop _ Vocab Chart.xlsx', sheet_name = 'Full')

# %%
fullsheet.head()
# Out:
#   notes  recalc    era     rapper rapper_clean                 color words  \
# 0   NaN  2988.0  2010s  21 Savage    21 Savage                   NaN  2988
# 1   NaN  3812.0  2010s   2 Chainz     2 Chainz                   NaN  4148
# 2   NaN  3815.0  1990s       2Pac         2Pac  west nowutang second  3970
# 3   NaN  3384.0  2000s    50 Cent      50 Cent   east nowutang first  3591
# 4   NaN  4534.0  2010s    Ab-Soul      Ab-Soul                   NaN  4534
#
#           id  source
# 0  21-savage     new
# 1    2chainz  poster
# 2       2pac    site
# 3    50-cent    site
# 4     absoul     new

# %%
improvedartistlinks = artistlinks[['Artist Slug', 'artist link']]

# %%
improvedfullsheet = fullsheet[['id','rapper','era','words','recalc']]

# %%
improvedfullsheetsort = improvedfullsheet.sort_values(by = 'recalc', ascending = False)

# %%
improvedfullsheetsort.head(50)
# Out:
#                      id                               rapper    era words  \
# 6                 aesop                           Aesop Rock  2000s  7392
# 24            busdriver                            Busdriver  2000s  7324
# 68                 jedi                     Jedi Mind Tricks  2000s  6336
# 57                  gza               GZA (only solo albums)  1990s  6426
# 156             wu-tang                         Wu-Tang Clan  1990s  5895
# 106             mf-doom                              MF DOOM  2000s  5204
# 131                 rza               RZA (only solo albums)  2000s  5905
# 61             immortal                   Immortal Technique  2000s  5841
# 27              canibus                              Canibus  2000s  5991
# 54     ghostface-killah  Ghostface Killah (only solo albums)  2000s  5774
# 38                  del             Del the Funky Homosapian  1990s  6135
# 127               roots                            The Roots  1990s  5803
# ...
